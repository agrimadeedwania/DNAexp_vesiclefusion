# %% [markdown]
# # Model with ATP rheostat

# %% [markdown]
# # Caution
#
# 1) If reaction names and specie names (or maybe Id) are same for two reaction, they are combined. Remember to change the reaction name before combining models if you want same reactions to be present (even for different compartments).
#
# 2) Do not change the membrane model and the external subsystem model. The ones that I have listed should be there. Add new models in the respective ListOfSubsystems according to mechanism you want to achieve.
#
# 3) Change internal subsystem of cells (cell_2 and cell_3) to be fused according to the objective you want to achieve.
#
# 4) Remeber to check the sbml file of generated model to verify if things are correct.
#
# 5) I am printing result 1 and 2 inorder to check if fusion occur at right time, specie concentration are set correctly

# %%
from biocrnpyler import *
import numpy as np
import pylab as plt
from subsbml import *
import libsbml
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1827">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Make individual cell model

# %%
ss1 = createSubsystem('Models/protein_rheostat_export.xml')
ss2 = createSubsystem('Models/atc_external_reservoir.xml')
#ssext= createSubsystem('Models/dnaStrand_fusion_export.xml')

# Create a simple atc membrane where atc goes in an out of the membrane via a reversible reaction
mb1 = createSubsystem('Models/atc_membrane_export.xml', membrane = True)

mb2 = createSubsystem('Models/dnaexp_membrane1.xml', membrane = True)

cell_1 =  System('cell_1',ListOfInternalSubsystems = [ss1],
                 ListOfExternalSubsystems = [ss2],
                 ListOfMembraneSubsystems = [mb1,mb2])

cell_1_model = cell_1.getModel()
cell_1_model.renameCompartments('cell_1_external', 'cell_external')
cell_1_model.getSBMLDocument().getModel().getCompartment(1).setSize(1e-4) 
#cell_1_model.getSBMLDocument().getModel().getCompartment(0).setSize(1e-10) 
cell_1_model.setSpeciesConcentration('atc_e', 1e4, compartment = 'cell_external')
cell_1_model.setSpeciesConcentration('ssDNA', 50, compartment = 'cell_1_internal')
cell_1_model.setSpeciesConcentration('dna_g', 1, compartment = 'cell_1_internal')
cell_1_model.setSpeciesConcentration('tetR', 10, compartment = 'cell_1_internal')
cell_1_model.setSpeciesConcentration('ATP', 15, compartment = 'cell_1_internal')
cell_1_model.setSpeciesConcentration('molecule_glucose', 30, compartment = 'cell_1_internal')
cell_1_model.setSpeciesConcentration('metabolite_nadp', 30, compartment = 'cell_1_internal')
cell_1_model.setSpeciesConcentration('P', 30, compartment = 'cell_1_internal')
cell_1_model.setSpeciesConcentration('enzyme_hex', 0.20, compartment = 'cell_1_internal')
cell_1_model.setSpeciesConcentration('enzyme_pgi', 0.20, compartment = 'cell_1_internal')
cell_1_model.setSpeciesConcentration('enzyme_pfk', 0.20, compartment = 'cell_1_internal')
cell_1_model.setSpeciesConcentration('enzyme_ald_tpi', 0.20, compartment = 'cell_1_internal')
cell_1_model.setSpeciesConcentration('enzyme_gapN', 0.20, compartment = 'cell_1_internal')
cell_1_model.setSpeciesConcentration('enzyme_mGapDH', 0.20, compartment = 'cell_1_internal')
cell_1_model.setSpeciesConcentration('enzyme_pgk', 0.20, compartment = 'cell_1_internal')
cell_1_model.setSpeciesConcentration('enzyme_pgm', 0.20, compartment = 'cell_1_internal')
cell_1_model.setSpeciesConcentration('enzyme_eno', 0.20, compartment = 'cell_1_internal')
cell_1_model.setSpeciesConcentration('enzyme_pyk', 0.20, compartment = 'cell_1_internal')
cell_1_model.setSpeciesConcentration('enzyme_alsS', 0.20, compartment = 'cell_1_internal')
cell_1_model.setSpeciesConcentration('enzyme_IlvC', 0.20, compartment = 'cell_1_internal')
cell_1_model.setSpeciesConcentration('enzyme_IlvD', 0.20, compartment = 'cell_1_internal')
cell_1_model.setSpeciesConcentration('enzyme_kivD', 0.20, compartment = 'cell_1_internal')
cell_1_model.setSpeciesConcentration('enzyme_yahk', 0.20, compartment = 'cell_1_internal')


cell_1_model.writeSBML('Models/m2Dnaexp_cell.xml')
# Out:
# The subsystem from Models/atc_membrane_export.xml has multiple compartments
# The subsystem from Models/dnaexp_membrane1.xml has multiple compartments
# 1

# %%
ss3 = createSubsystem('Models/comb_exsA_sub.xml')
mb3 = createSubsystem('Models/atc_membrane_cell2.xml', membrane = True)
cell_2 =  System('cell_2',ListOfInternalSubsystems = [ss3],
                 ListOfExternalSubsystems = [ss2],
                 ListOfMembraneSubsystems = [mb3])

cell_2_model = cell_2.getModel()
#cell_2_model.renameSName('atc_i', 'atc_i_cell2')
cell_2_model.renameCompartments('cell_2_external', 'cell_external')
cell_2_model.getSBMLDocument().getModel().getCompartment(0).setSize(1e-4) 
#cell_2_model.getSBMLDocument().getModel().getCompartment(1).setSize(1e-10) 

cell_2_model.setSpeciesConcentration('atc_e', 1e4, compartment = 'cell_external')
cell_2_model.setSpeciesConcentration('ssDNA_comp1', 10, compartment = 'cell_2_internal')
cell_2_model.setSpeciesConcentration('dna_f', 1, compartment = 'cell_2_internal')
cell_2_model.setSpeciesConcentration('tetR', 10, compartment = 'cell_2_internal')
cell_2_model.setSpeciesConcentration('ATP', 15, compartment = 'cell_2_internal')
cell_2_model.setSpeciesConcentration('molecule_glucose', 30, compartment = 'cell_2_internal')
cell_2_model.setSpeciesConcentration('metabolite_nadp', 30, compartment = 'cell_2_internal')
cell_2_model.setSpeciesConcentration('P', 30, compartment = 'cell_2_internal')
cell_2_model.setSpeciesConcentration('enzyme_hex', 0.20, compartment = 'cell_2_internal')
cell_2_model.setSpeciesConcentration('enzyme_pgi', 0.20, compartment = 'cell_2_internal')
cell_2_model.setSpeciesConcentration('enzyme_pfk', 0.20, compartment = 'cell_2_internal')
cell_2_model.setSpeciesConcentration('enzyme_ald_tpi', 0.20, compartment = 'cell_2_internal')
cell_2_model.setSpeciesConcentration('enzyme_gapN', 0.20, compartment = 'cell_2_internal')
cell_2_model.setSpeciesConcentration('enzyme_mGapDH', 0.20, compartment = 'cell_2_internal')
cell_2_model.setSpeciesConcentration('enzyme_pgk', 0.20, compartment = 'cell_2_internal')
cell_2_model.setSpeciesConcentration('enzyme_pgm', 0.20, compartment = 'cell_2_internal')
cell_2_model.setSpeciesConcentration('enzyme_eno', 0.20, compartment = 'cell_2_internal')
cell_2_model.setSpeciesConcentration('enzyme_pyk', 0.20, compartment = 'cell_2_internal')
cell_2_model.setSpeciesConcentration('enzyme_alsS', 0.20, compartment = 'cell_2_internal')
cell_2_model.setSpeciesConcentration('enzyme_IlvC', 0.20, compartment = 'cell_2_internal')
cell_2_model.setSpeciesConcentration('enzyme_IlvD', 0.20, compartment = 'cell_2_internal')
cell_2_model.setSpeciesConcentration('enzyme_kivD', 0.20, compartment = 'cell_2_internal')
cell_2_model.setSpeciesConcentration('enzyme_yahk', 0.20, compartment = 'cell_2_internal')


cell_2_model.writeSBML('Models/m2fusion_cell1.xml')
# Out:
# The subsystem from Models/atc_membrane_cell2.xml has multiple compartments
# 1

# %%
ss5 = createSubsystem('Models/comb_gfp1_sub.xml')
mb4 = createSubsystem('Models/atc_membrane_cell3.xml', membrane = True)
cell_3 =  System('cell_3',ListOfInternalSubsystems = [ss5],
                 ListOfExternalSubsystems = [ss2],
                 ListOfMembraneSubsystems = [mb4])

cell_3_model = cell_3.getModel()

cell_3_model.renameCompartments('cell_3_external', 'cell_external')
cell_3_model.getSBMLDocument().getModel().getCompartment(0).setSize(1e-4) 
#cell_3_model.getSBMLDocument().getModel().getCompartment(1).setSize(1e-10) 

cell_3_model.setSpeciesConcentration('atc_e', 1e4, compartment = 'cell_external')
cell_3_model.setSpeciesConcentration('ssDNA_comp2', 10, compartment = 'cell_3_internal')
cell_3_model.setSpeciesConcentration('dna_h', 1, compartment = 'cell_3_internal')
cell_3_model.setSpeciesConcentration('ATP', 15, compartment = 'cell_3_internal')
cell_3_model.setSpeciesConcentration('molecule_glucose', 30, compartment = 'cell_3_internal')
cell_3_model.setSpeciesConcentration('metabolite_nadp', 30, compartment = 'cell_3_internal')
cell_3_model.setSpeciesConcentration('P', 30, compartment = 'cell_3_internal')
cell_3_model.setSpeciesConcentration('enzyme_hex', 0.20, compartment = 'cell_3_internal')
cell_3_model.setSpeciesConcentration('enzyme_pgi', 0.20, compartment = 'cell_3_internal')
cell_3_model.setSpeciesConcentration('enzyme_pfk', 0.20, compartment = 'cell_3_internal')
cell_3_model.setSpeciesConcentration('enzyme_ald_tpi', 0.20, compartment = 'cell_3_internal')
cell_3_model.setSpeciesConcentration('enzyme_gapN', 0.20, compartment = 'cell_3_internal')
cell_3_model.setSpeciesConcentration('enzyme_mGapDH', 0.20, compartment = 'cell_3_internal')
cell_3_model.setSpeciesConcentration('enzyme_pgk', 0.20, compartment = 'cell_3_internal')
cell_3_model.setSpeciesConcentration('enzyme_pgm', 0.20, compartment = 'cell_3_internal')
cell_3_model.setSpeciesConcentration('enzyme_eno', 0.20, compartment = 'cell_3_internal')
cell_3_model.setSpeciesConcentration('enzyme_pyk', 0.20, compartment = 'cell_3_internal')
cell_3_model.setSpeciesConcentration('enzyme_alsS', 0.20, compartment = 'cell_3_internal')
cell_3_model.setSpeciesConcentration('enzyme_IlvC', 0.20, compartment = 'cell_3_internal')
cell_3_model.setSpeciesConcentration('enzyme_IlvD', 0.20, compartment = 'cell_3_internal')
cell_3_model.setSpeciesConcentration('enzyme_kivD', 0.20, compartment = 'cell_3_internal')
cell_3_model.setSpeciesConcentration('enzyme_yahk', 0.20, compartment = 'cell_3_internal')

cell_3_model.writeSBML('Models/m2fusion_cell2.xml')
# Out:
# The subsystem from Models/atc_membrane_cell3.xml has multiple compartments
# 1

# %%
system2 = createNewSubsystem() 
system2.combineSubsystems([cell_1_model, cell_2_model, cell_3_model], verbose=True)
system2.writeSBML('Models/m2system2.xml')
combmod2=system2.getSBMLDocument().getModel()
combinemodel2=SimpleModel(combmod2)
combinemodel2.createNewSpecies(ListOfSpecies = ['dsDNA'],sComp = 'cell_external_combined', ListOfAmounts = [0], 
                             sConstant = False)
combinemodel2.createNewParameter(ListOfParameters = ['kf','kre'],
                               ListOfValues = [100, 1e-7],
                               pConstant = False, pUnit = 'per_second')
combinemodel2.createSimpleReaction(rId = 'raa1',rStr = 'ssDNA_comp1 + ssDNA_comp2 + ssDNA_e <-> dsDNA',
                                 rRate = 'kf * ssDNA_comp1 * ssDNA_comp2 * ssDNA_e - kre * dsDNA',
                                 isConstant = False)

system2.writeSBML('Models/m3system32.xml')
# Out:
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:646: UserWarning: Not all of the Subsystems being combined are in the same Compartment
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:989: UserWarning: Annotated propensity updated to: <PropensityType> type=massaction k=0.0002  </PropensityType>
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:989: UserWarning: Annotated propensity updated to: <PropensityType> type=massaction k=2e-09  </PropensityType>
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:989: UserWarning: Annotated propensity updated to: <PropensityType> type=massaction k=4e-05  </PropensityType>
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:989: UserWarning: Annotated propensity updated to: <PropensityType> type=massaction k=1e-12  </PropensityType>
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:989: UserWarning: Annotated propensity updated to: <PropensityType> type=massaction k=6e-06  </PropensityType>
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:989: UserWarning: Annotated propensity updated to: <PropensityType> type=massaction k=3e-09  </PropensityType>
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:989: UserWarning: Annotated propensity updated to: <PropensityType> type=massaction k=0.005  </PropensityType>
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:989: UserWarning: Annotated propensity updated to: <PropensityType> type=massaction k=1e-10  </PropensityType>
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:989: UserWarning: Annotated propensity updated to: <PropensityType> type=massaction k=0.0031875  </PropensityType>
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:989: UserWarning: Annotated propensity updated to: <PropensityType> type=proportionalhillpositive k=0.001 K=1 n=1 s1=ATP_virE2biocrnpyler_454852_1_combined_combined_model_of__biocrnpyler_454852_biocrnpyler_317929 d=rna_g_virE2biocrnpyler_454852_combined_model_of__biocrnpyler_454852_biocrnpyler_317929  </PropensityType>
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:989: UserWarning: Annotated propensity updated to: <PropensityType> type=massaction k=5e-05  </PropensityType>
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:989: UserWarning: Annotated propensity updated to: <PropensityType> type=massaction k=0.001  </PropensityType>
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:989: UserWarning: Annotated propensity updated to: <PropensityType> type=massaction k=1e-05  </PropensityType>
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:989: UserWarning: Annotated propensity updated to: <PropensityType> type=massaction k=0.03  </PropensityType>
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:989: UserWarning: Annotated propensity updated to: <PropensityType> type=massaction k=0.003  </PropensityType>
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:989: UserWarning: Annotated propensity updated to: <PropensityType> type=massaction k=36000  </PropensityType>
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:989: UserWarning: Annotated propensity updated to: <PropensityType> type=massaction k=2e-05  </PropensityType>
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:989: UserWarning: Annotated propensity updated to: <PropensityType> type=massaction k=4e-07  </PropensityType>
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:989: UserWarning: Annotated propensity updated to: <PropensityType> type=massaction k=6e-08  </PropensityType>
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:989: UserWarning: Annotated propensity updated to: <PropensityType> type=massaction k=0.001875  </PropensityType>
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:989: UserWarning: Annotated propensity updated to: <PropensityType> type=proportionalhillpositive k=0.0005 K=1 n=1 s1=ATP_exsAbiocrnpyler_367767_1_combined_combined_model_of__biocrnpyler_367767_biocrnpyler_317929 d=rna_f_exsAbiocrnpyler_367767_combined_model_of__biocrnpyler_367767_biocrnpyler_317929  </PropensityType>
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:989: UserWarning: Annotated propensity updated to: <PropensityType> type=proportionalhillpositive k=0.0005 K=1 n=1 s1=ATP_gfpbiocrnpyler_798952_1_combined_combined_model_of__biocrnpyler_798952_biocrnpyler_317929 d=rna_h_gfpbiocrnpyler_798952_combined_model_of__biocrnpyler_798952_biocrnpyler_317929  </PropensityType>
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1173: UserWarning: Removing duplicate species atc_e_external_reservoir_model_1_combined_1_combined in the same compartment
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1282: UserWarning: Removing duplicate parameter kb from the combined model
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1282: UserWarning: Removing duplicate parameter kd from the combined model
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction enzyme_hex + ATP + molecule_glucose --> complex_enzyme_hex_metabolite_atp_molecule_glucoser0 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction complex_enzyme_hex_metabolite_atp_molecule_glucose --> enzyme_hex + ATP + molecule_glucoser0_1 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction complex_enzyme_hex_metabolite_atp_molecule_glucose --> complex_enzyme_hex_metabolite_adp_molecule_g6pr2 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction complex_enzyme_hex_metabolite_adp_molecule_g6p --> enzyme_hex + molecule_g6p + ADPr3 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction enzyme_hex + molecule_g6p + ADP --> complex_enzyme_hex_metabolite_adp_molecule_g6pr3_1 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction enzyme_pgi + molecule_g6p --> complex_enzyme_pgi_molecule_g6pr5 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction complex_enzyme_pgi_molecule_g6p --> enzyme_pgi + molecule_g6pr5_1 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction complex_enzyme_pgi_molecule_g6p --> complex_enzyme_pgi_molecule_f6pr7 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction complex_enzyme_pgi_molecule_f6p --> enzyme_pgi + molecule_f6pr8 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction enzyme_pgi + molecule_f6p --> complex_enzyme_pgi_molecule_f6pr8_1 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction enzyme_pfk + ATP + molecule_f6p --> complex_enzyme_pfk_metabolite_atp_molecule_f6pr10 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction complex_enzyme_pfk_metabolite_atp_molecule_f6p --> enzyme_pfk + ATP + molecule_f6pr10_1 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction complex_enzyme_pfk_metabolite_atp_molecule_f6p --> complex_enzyme_pfk_metabolite_adp_molecule_f16pr12 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction complex_enzyme_pfk_metabolite_adp_molecule_f16p --> enzyme_pfk + molecule_f16p + ADPr13 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction enzyme_pfk + molecule_f16p + ADP --> complex_enzyme_pfk_metabolite_adp_molecule_f16pr13_1 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction enzyme_ald_tpi + molecule_f16p --> complex_enzyme_ald_tpi_molecule_f16pr15 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction complex_enzyme_ald_tpi_molecule_f16p --> enzyme_ald_tpi + molecule_f16pr15_1 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction complex_enzyme_ald_tpi_molecule_f16p --> complex_enzyme_ald_tpi_2x_molecule_g3pr17 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction complex_enzyme_ald_tpi_2x_molecule_g3p --> enzyme_ald_tpi + molecule_g3pr18 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction enzyme_ald_tpi + molecule_g3p --> complex_enzyme_ald_tpi_2x_molecule_g3pr18_1 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction enzyme_gapN + metabolite_nadp + molecule_g3p --> complex_enzyme_gapN_2x_metabolite_nadp_2x_molecule_g3pr20 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction complex_enzyme_gapN_2x_metabolite_nadp_2x_molecule_g3p --> enzyme_gapN + metabolite_nadp + molecule_g3pr20_1 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction complex_enzyme_gapN_2x_metabolite_nadp_2x_molecule_g3p --> complex_enzyme_gapN_2x_metabolite_nadph_2x_molecule_3pgr22 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction complex_enzyme_gapN_2x_metabolite_nadph_2x_molecule_3pg --> enzyme_gapN + molecule_3pg + metabolite_nadphr23 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction enzyme_gapN + molecule_3pg + metabolite_nadph --> complex_enzyme_gapN_2x_metabolite_nadph_2x_molecule_3pgr23_1 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction enzyme_mGapDH + P + metabolite_nadp + molecule_g3p --> complex_enzyme_mGapDH_2x_metabolite_nadp_metabolite_pi_2x_molecule_g3pr25 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction complex_enzyme_mGapDH_2x_metabolite_nadp_metabolite_pi_2x_molecule_g3p --> enzyme_mGapDH + P + metabolite_nadp + molecule_g3pr25_1 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction complex_enzyme_mGapDH_2x_metabolite_nadp_metabolite_pi_2x_molecule_g3p --> complex_enzyme_mGapDH_2x_metabolite_nadph_molecule_13bpgr27 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction complex_enzyme_mGapDH_2x_metabolite_nadph_molecule_13bpg --> enzyme_mGapDH + molecule_13bpg + metabolite_nadphr28 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction enzyme_mGapDH + molecule_13bpg + metabolite_nadph --> complex_enzyme_mGapDH_2x_metabolite_nadph_molecule_13bpgr28_1 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction enzyme_pgk + ADP + molecule_13bpg --> complex_enzyme_pgk_metabolite_adp_molecule_13bpgr30 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction complex_enzyme_pgk_metabolite_adp_molecule_13bpg --> enzyme_pgk + ADP + molecule_13bpgr30_1 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction complex_enzyme_pgk_metabolite_adp_molecule_13bpg --> complex_enzyme_pgk_metabolite_atp_2x_molecule_3pgr32 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction complex_enzyme_pgk_metabolite_atp_2x_molecule_3pg --> enzyme_pgk + molecule_3pg + ATPr33 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction enzyme_pgk + molecule_3pg + ATP --> complex_enzyme_pgk_metabolite_atp_2x_molecule_3pgr33_1 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction enzyme_pgm + molecule_3pg --> complex_enzyme_pgm_2x_molecule_3pgr35 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction complex_enzyme_pgm_2x_molecule_3pg --> enzyme_pgm + molecule_3pgr35_1 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction complex_enzyme_pgm_2x_molecule_3pg --> complex_enzyme_pgm_2x_molecule_2pgr37 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction complex_enzyme_pgm_2x_molecule_2pg --> enzyme_pgm + molecule_2pgr38 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction enzyme_pgm + molecule_2pg --> complex_enzyme_pgm_2x_molecule_2pgr38_1 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction enzyme_eno + molecule_2pg --> complex_enzyme_eno_2x_molecule_2pgr40 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction complex_enzyme_eno_2x_molecule_2pg --> enzyme_eno + molecule_2pgr40_1 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction complex_enzyme_eno_2x_molecule_2pg --> complex_enzyme_eno_2x_molecule_pepr42 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction complex_enzyme_eno_2x_molecule_pep --> enzyme_eno + molecule_pepr43 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction enzyme_eno + molecule_pep --> complex_enzyme_eno_2x_molecule_pepr43_1 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction enzyme_pyk + ADP + molecule_pep --> complex_enzyme_pyk_2x_metabolite_adp_2x_molecule_pepr45 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction complex_enzyme_pyk_2x_metabolite_adp_2x_molecule_pep --> enzyme_pyk + ADP + molecule_pepr45_1 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction complex_enzyme_pyk_2x_metabolite_adp_2x_molecule_pep --> complex_enzyme_pyk_2x_metabolite_atp_2x_molecule_pyruvater47 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction complex_enzyme_pyk_2x_metabolite_atp_2x_molecule_pyruvate --> enzyme_pyk + molecule_pyruvate + ATPr48 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction enzyme_pyk + molecule_pyruvate + ATP --> complex_enzyme_pyk_2x_metabolite_atp_2x_molecule_pyruvater48_1 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction enzyme_alsS + molecule_pyruvate --> complex_enzyme_alsS_2x_molecule_pyruvater50 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction complex_enzyme_alsS_2x_molecule_pyruvate --> enzyme_alsS + molecule_pyruvater50_1 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction complex_enzyme_alsS_2x_molecule_pyruvate --> complex_enzyme_alsS_molecule_acetolacr52 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction complex_enzyme_alsS_molecule_acetolac --> enzyme_alsS + molecule_acetolacr53 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction enzyme_alsS + molecule_acetolac --> complex_enzyme_alsS_molecule_acetolacr53_1 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction enzyme_IlvC + metabolite_nadph + molecule_acetolac --> complex_enzyme_IlvC_metabolite_nadph_molecule_acetolacr55 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction complex_enzyme_IlvC_metabolite_nadph_molecule_acetolac --> enzyme_IlvC + metabolite_nadph + molecule_acetolacr55_1 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction complex_enzyme_IlvC_metabolite_nadph_molecule_acetolac --> complex_enzyme_IlvC_metabolite_nadp_molecule_23dih3mebutr57 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction complex_enzyme_IlvC_metabolite_nadp_molecule_23dih3mebut --> enzyme_IlvC + molecule_23dih3mebut + metabolite_nadpr58 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction enzyme_IlvC + molecule_23dih3mebut + metabolite_nadp --> complex_enzyme_IlvC_metabolite_nadp_molecule_23dih3mebutr58_1 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction enzyme_IlvD + molecule_23dih3mebut --> complex_enzyme_IlvD_molecule_23dih3mebutr60 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction complex_enzyme_IlvD_molecule_23dih3mebut --> enzyme_IlvD + molecule_23dih3mebutr60_1 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction complex_enzyme_IlvD_molecule_23dih3mebut --> complex_enzyme_IlvD_molecule_3me2oxor62 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction complex_enzyme_IlvD_molecule_3me2oxo --> enzyme_IlvD + molecule_3me2oxor63 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction enzyme_IlvD + molecule_3me2oxo --> complex_enzyme_IlvD_molecule_3me2oxor63_1 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction enzyme_kivD + molecule_3me2oxo --> complex_enzyme_kivD_molecule_3me2oxor65 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction complex_enzyme_kivD_molecule_3me2oxo --> enzyme_kivD + molecule_3me2oxor65_1 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction complex_enzyme_kivD_molecule_3me2oxo --> complex_enzyme_kivD_molecule_isobutanalr67 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction complex_enzyme_kivD_molecule_isobutanal --> enzyme_kivD + molecule_isobutanalr68 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction enzyme_kivD + molecule_isobutanal --> complex_enzyme_kivD_molecule_isobutanalr68_1 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction enzyme_yahk + metabolite_nadph + molecule_isobutanal --> complex_enzyme_yahk_metabolite_nadph_molecule_isobutanalr70 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction complex_enzyme_yahk_metabolite_nadph_molecule_isobutanal --> enzyme_yahk + metabolite_nadph + molecule_isobutanalr70_1 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction complex_enzyme_yahk_metabolite_nadph_molecule_isobutanal --> complex_enzyme_yahk_metabolite_nadp_molecule_isobutanolr72 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction complex_enzyme_yahk_metabolite_nadp_molecule_isobutanol --> enzyme_yahk + molecule_isobutanol + metabolite_nadpr73 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1500: UserWarning: Removing all duplicates of the reaction enzyme_yahk + molecule_isobutanol + metabolite_nadp --> complex_enzyme_yahk_metabolite_nadp_molecule_isobutanolr73_1 in the combined model. Check the reaction rate to ensure model is consistent.
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1547: UserWarning: UnitDefinition with identifier square_metre does not have a name argument. To avoid duplication, use name argument
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1547: UserWarning: UnitDefinition with identifier per_second does not have a name argument. To avoid duplication, use name argument
# C:\Users\Agrima\anaconda3\lib\site-packages\subsbml-0.1-py3.7.egg\subsbml\Subsystem.py:1547: UserWarning: UnitDefinition with identifier substance does not have a name argument. To avoid duplication, use name argument
# 1

# %%
system2.setSpeciesConcentration('atc_e', 1e4, compartment = 'cell_external')
system2.setSpeciesConcentration('ssDNA', 50, compartment = 'cell_1_internal')
system2.setSpeciesConcentration('dna_g', 1, compartment = 'cell_1_internal')
system2.setSpeciesConcentration('tetR', 10, compartment = 'cell_1_internal')
system2.setSpeciesConcentration('ATP', 15, compartment = 'cell_1_internal')
system2.setSpeciesConcentration('ssDNA_comp1', 10, compartment = 'cell_2_internal')
system2.setSpeciesConcentration('dna_f', 1, compartment = 'cell_2_internal')
system2.setSpeciesConcentration('tetR', 10, compartment = 'cell_2_internal')
system2.setSpeciesConcentration('ATP', 10, compartment = 'cell_2_internal')
system2.setSpeciesConcentration('ssDNA_comp2', 10, compartment = 'cell_3_internal')
system2.setSpeciesConcentration('dna_h', 1, compartment = 'cell_3_internal')
system2.setSpeciesConcentration('ATP', 15, compartment = 'cell_3_internal')
system2.writeSBML('Models/m3system32.xml')
# Out:
# 1

# %%
timepoints = np.linspace(0,45000,1000)
result1, _ = system2.simulateWithBioscrape(timepoints)
ssDNA_e_id1 = system2.getSpeciesByName('ssDNA_e', compartment = 'cell_external').getId()
ATP_id1= system2.getSpeciesByName('ATP', compartment = 'cell_1_internal').getId()
dsDNA_id2 =system2.getSpeciesByName('dsDNA').getId()
vire2b_id2 =system2.getSpeciesByName('VirE2_b').getId()
plt.figure(figsize=(12,6))
plt.plot(timepoints, result1[ssDNA_e_id1], linewidth = 3, label = 'ssDNA_e')
plt.plot(timepoints, result1[dsDNA_id2], linewidth = 3, label = 'dsDNA')
plt.title("Model")
plt.xlabel('Time')
plt.ylabel('Conc')
plt.legend()
plt.show()
# Out:
# C:\Users\Agrima\anaconda3\lib\site-packages\bioscrape\sbmlutil.py:93: UserWarning: SBML model contains reversible reaction!
# Please check rate expressions and ensure they are non-negative before doing stochastic simulations.
#   'Please check rate expressions and ensure they are non-negative before doing '+
# C:\Users\Agrima\anaconda3\lib\site-packages\bioscrape\sbmlutil.py:208: UserWarning: Compartments, UnitDefintions, Events, and some other SBML model components are not recognized by bioscrape. Refer to the bioscrape wiki for more information.
#   warnings.warn('Compartments, UnitDefintions, Events, and some other SBML model components are not recognized by bioscrape. ' +

# %%
# %run myfusion.py

# %%
fused_cell,r1,t1,r2,t2= triggeredFusion ( [system2], [cell_2_model, cell_3_model], "dsDNA", ">", 1, timepoints)
# Out:
# C:\Users\Agrima\anaconda3\lib\site-packages\bioscrape\sbmlutil.py:93: UserWarning: SBML model contains reversible reaction!
# Please check rate expressions and ensure they are non-negative before doing stochastic simulations.
#   'Please check rate expressions and ensure they are non-negative before doing '+
# C:\Users\Agrima\anaconda3\lib\site-packages\bioscrape\sbmlutil.py:208: UserWarning: Compartments, UnitDefintions, Events, and some other SBML model components are not recognized by bioscrape. Refer to the bioscrape wiki for more information.
#   warnings.warn('Compartments, UnitDefintions, Events, and some other SBML model components are not recognized by bioscrape. ' +

# %%
print(r1)
# Out:
#     atc_e_external_reservoir_model_1_combined  ssDNA_comp1  \
# 0                                10000.000000         10.0
# 1                                 9138.679103         10.0
# 2                                 8351.914508         10.0
# 3                                 7633.253001         10.0
# 4                                 6976.800382         10.0
# ..                                        ...          ...
# 71                                  65.771913         10.0
# 72                                  64.380814         10.0
# 73                                  63.110132         10.0
# 74                                  61.949444         10.0
# 75                                  60.889228         10.0
#
#     dna_f_exsAbiocrnpyler_367767_combined_model_of__biocrnpyler_367767_biocrnpyler_317929  \
# 0                                            1.000000
# 1                                            0.999841
# 2                                            0.999764
# 3                                            0.999745
# 4                                            0.999742
# ..                                                ...
# 71                                           0.999756
# 72                                           0.999757
# 73                                           0.999757
# 74                                           0.999758
# 75                                           0.999758
#
#     tetR_exsAbiocrnpyler_367767_combined_model_of__biocrnpyler_367767_biocrnpyler_317929  \
# 0                                        1.000000e+01
# 1                                        6.751682e+00
# 2                                        2.179754e+00
# 3                                        3.583946e-01
# 4                                        3.175793e-02
# ..                                                ...
# 71                                       1.007625e-07
# 72                                       1.007483e-07
# 73                                       1.007352e-07
# 74                                       1.007233e-07
# 75                                       1.007125e-07
#
#     rna_f_exsAbiocrnpyler_367767_combined_model_of__biocrnpyler_367767_biocrnpyler_317929  \
# 0                                            0.000000
# 1                                            0.082578
# 2                                            0.161510
# 3                                            0.236961
# 4                                            0.309088
# ..                                                ...
# 71                                           1.797985
# 72                                           1.801357
# 73                                           1.804580
# 74                                           1.807662
# 75                                           1.810608
#
#     exsA_exsAbiocrnpyler_367767_combined_model_of__biocrnpyler_367767_biocrnpyler_317929  \
# 0                                            0.000000
# 1                                            0.000877
# 2                                            0.003453
# 3                                            0.007648
# 4                                            0.013384
# ..                                                ...
# 71                                           1.786701
# 72                                           1.820029
# 73                                           1.853425
# 74                                           1.886888
# 75                                           1.920417
#
#     atc_i_cell2_1_combined  \
# 0                 0.000000
# 1               858.072738
# 2              1640.265481
# 3              2357.105646
# 4              3013.231630
# ..                     ...
# 71             9924.228139
# 72             9925.619236
# 73             9926.889917
# 74             9928.050604
# 75             9929.110818
#
#     complex_atc_i_cell2_tetR_exsAbiocrnpyler_367767_combined_model_of__biocrnpyler_367767_biocrnpyler_317929  \
# 0                                            0.000000
# 1                                            3.248159
# 2                                            7.820010
# 3                                            9.641350
# 4                                            9.967984
# ..                                                ...
# 71                                           9.999756
# 72                                           9.999757
# 73                                           9.999757
# 74                                           9.999757
# 75                                           9.999758
#
#     complex_dna_f_tetR_exsAbiocrnpyler_367767_combined_model_of__biocrnpyler_367767_biocrnpyler_317929  \
# 0                                            0.000000
# 1                                            0.000159
# 2                                            0.000235
# 3                                            0.000253
# 4                                            0.000254
# ..                                                ...
# 71                                           0.000052
# 72                                           0.000050
# 73                                           0.000049
# 74                                           0.000048
# 75                                           0.000046
#
#     complex_atc_i_cell2_dna_f_tetR_exsAbiocrnpyler_367767_combined_model_of__biocrnpyler_367767_biocrnpyler_317929  \
# 0                                        0.000000e+00
# 1                                        1.358339e-07
# 2                                        8.661583e-07
# 3                                        2.243156e-06
# 4                                        4.126863e-06
# ..                                                ...
# 71                                       1.919897e-04
# 72                                       1.929671e-04
# 73                                       1.939063e-04
# 74                                       1.948084e-04
# 75                                       1.956744e-04
#
#     ...  \
# 0   ...
# 1   ...
# 2   ...
# 3   ...
# 4   ...
# ..  ...
# 71  ...
# 72  ...
# 73  ...
# 74  ...
# 75  ...
#
#     complex_enzyme_IlvD_molecule_3me2oxo_ATP_rheostatbiocrnpyler_317929_combined_model_of__biocrnpyler_798952_biocrnpyler_317929  \
# 0                                        0.000000e+00
# 1                                        2.287777e-28
# 2                                        7.664123e-21
# 3                                        1.103141e-16
# 4                                        6.709435e-14
# ..                                                ...
# 71                                       1.031044e-01
# 72                                       1.038692e-01
# 73                                       1.046159e-01
# 74                                       1.053453e-01
# 75                                       1.060578e-01
#
#     enzyme_kivD_ATP_rheostatbiocrnpyler_317929_combined_model_of__biocrnpyler_798952_biocrnpyler_317929  \
# 0                                            0.200000
# 1                                            0.200000
# 2                                            0.200000
# 3                                            0.200000
# 4                                            0.200000
# ..                                                ...
# 71                                           0.110505
# 72                                           0.109628
# 73                                           0.108770
# 74                                           0.107931
# 75                                           0.107110
#
#     molecule_isobutanal_ATP_rheostatbiocrnpyler_317929_combined_model_of__biocrnpyler_798952_biocrnpyler_317929  \
# 0                                        0.000000e+00
# 1                                        6.563507e-33
# 2                                        1.487885e-24
# 3                                        7.894267e-20
# 4                                        1.227941e-16
# ..                                                ...
# 71                                       3.963694e-01
# 72                                       4.082115e-01
# 73                                       4.200742e-01
# 74                                       4.319522e-01
# 75                                       4.438405e-01
#
#     complex_enzyme_kivD_molecule_3me2oxo_ATP_rheostatbiocrnpyler_317929_combined_model_of__biocrnpyler_798952_biocrnpyler_317929  \
# 0                                        0.000000e+00
# 1                                        2.065383e-36
# 2                                        1.336930e-28
# 3                                        3.009492e-24
# 4                                        2.530607e-21
# ..                                                ...
# 71                                       7.147573e-08
# 72                                       7.211539e-08
# 73                                       7.274016e-08
# 74                                       7.335059e-08
# 75                                       7.394719e-08
#
#     complex_enzyme_kivD_molecule_isobutanal_ATP_rheostatbiocrnpyler_317929_combined_model_of__biocrnpyler_798952_biocrnpyler_317929  \
# 0                                        0.000000e+00
# 1                                        1.258634e-31
# 2                                        1.501341e-23
# 3                                        5.068865e-19
# 4                                        5.656036e-16
# ..                                                ...
# 71                                       8.949446e-02
# 72                                       9.037171e-02
# 73                                       9.122957e-02
# 74                                       9.206867e-02
# 75                                       9.288965e-02
#
#     enzyme_yahk_ATP_rheostatbiocrnpyler_317929_combined_model_of__biocrnpyler_798952_biocrnpyler_317929  \
# 0                                            0.200000
# 1                                            0.200000
# 2                                            0.200000
# 3                                            0.200000
# 4                                            0.200000
# ..                                                ...
# 71                                           0.019032
# 72                                           0.018458
# 73                                           0.017913
# 74                                           0.017397
# 75                                           0.016906
#
#     molecule_isobutanol_ATP_rheostatbiocrnpyler_317929_combined_model_of__biocrnpyler_798952_biocrnpyler_317929  \
# 0                                        0.000000e+00
# 1                                        8.642396e-42
# 2                                        6.914427e-31
# 3                                        9.003727e-25
# 4                                        1.114772e-20
# ..                                                ...
# 71                                       2.909652e+00
# 72                                       3.012785e+00
# 73                                       3.116973e+00
# 74                                       3.222193e+00
# 75                                       3.328425e+00
#
#     complex_enzyme_yahk_metabolite_nadph_molecule_isobutanal_ATP_rheostatbiocrnpyler_317929_combined_model_of__biocrnpyler_798952_biocrnpyler_317929  \
# 0                                        0.000000e+00
# 1                                        4.037910e-45
# 2                                        1.057419e-34
# 3                                        5.830834e-29
# 4                                        3.860386e-25
# ..                                                ...
# 71                                       6.363345e-08
# 72                                       6.427095e-08
# 73                                       6.489642e-08
# 74                                       6.551033e-08
# 75                                       6.611308e-08
#
#     complex_enzyme_yahk_metabolite_nadp_molecule_isobutanol_ATP_rheostatbiocrnpyler_317929_combined_model_of__biocrnpyler_798952_biocrnpyler_317929  \
# 0                                        0.000000e+00
# 1                                        2.034598e-40
# 2                                        9.385861e-30
# 3                                        7.903581e-24
# 4                                        7.114827e-20
# ..                                                ...
# 71                                       1.809679e-01
# 72                                       1.815422e-01
# 73                                       1.820866e-01
# 74                                       1.826033e-01
# 75                                       1.830941e-01
#
#            time
# 0      0.000000
# 1     45.045045
# 2     90.090090
# 3    135.135135
# 4    180.180180
# ..          ...
# 71  3198.198198
# 72  3243.243243
# 73  3288.288288
# 74  3333.333333
# 75  3378.378378
#
# [76 rows x 150 columns]

# %%
r2
# Out:
#      ssDNA_comp1  \
# 0           10.0
# 1           10.0
# 2           10.0
# 3           10.0
# 4           10.0
# ..           ...
# 920         10.0
# 921         10.0
# 922         10.0
# 923         10.0
# 924         10.0
#
#      dna_f_exsAbiocrnpyler_367767_combined_model_of__biocrnpyler_367767_biocrnpyler_317929  \
# 0                                             0.999758
# 1                                             0.999758
# 2                                             0.999759
# 3                                             0.999759
# 4                                             0.999760
# ..                                                 ...
# 920                                           0.999952
# 921                                           0.999952
# 922                                           0.999952
# 923                                           0.999952
# 924                                           0.999952
#
#      tetR_exsAbiocrnpyler_367767_combined_model_of__biocrnpyler_367767_biocrnpyler_317929  \
# 0                                         1.007125e-07
# 1                                         1.007029e-07
# 2                                         1.006948e-07
# 3                                         1.006881e-07
# 4                                         1.006825e-07
# ..                                                 ...
# 920                                       1.006392e-07
# 921                                       1.006392e-07
# 922                                       1.006392e-07
# 923                                       1.006391e-07
# 924                                       1.006391e-07
#
#      rna_f_exsAbiocrnpyler_367767_combined_model_of__biocrnpyler_367767_biocrnpyler_317929  \
# 0                                             1.810608
# 1                                             1.813424
# 2                                             1.816116
# 3                                             1.818690
# 4                                             1.821150
# ..                                                 ...
# 920                                           1.874906
# 921                                           1.874906
# 922                                           1.874907
# 923                                           1.874907
# 924                                           1.874907
#
#      atc_i_cell2_1_combined  \
# 0               9929.110818
# 1               9930.041830
# 2               9930.819356
# 3               9931.468759
# 4               9932.011213
# ..                      ...
# 920             9936.418900
# 921             9936.420380
# 922             9936.421860
# 923             9936.423339
# 924             9936.424817
#
#      complex_atc_i_cell2_tetR_exsAbiocrnpyler_367767_combined_model_of__biocrnpyler_367767_biocrnpyler_317929  \
# 0                                             9.999758
# 1                                             9.999758
# 2                                             9.999759
# 3                                             9.999759
# 4                                             9.999759
# ..                                                 ...
# 920                                           9.999951
# 921                                           9.999951
# 922                                           9.999952
# 923                                           9.999952
# 924                                           9.999952
#
#      complex_dna_f_tetR_exsAbiocrnpyler_367767_combined_model_of__biocrnpyler_367767_biocrnpyler_317929  \
# 0                                         4.635424e-05
# 1                                         4.512681e-05
# 2                                         4.393179e-05
# 3                                         4.276833e-05
# 4                                         4.163562e-05
# ..                                                 ...
# 920                                       3.246610e-10
# 921                                       3.243088e-10
# 922                                       3.239574e-10
# 923                                       3.236068e-10
# 924                                       3.232571e-10
#
#      complex_atc_i_cell2_dna_f_tetR_exsAbiocrnpyler_367767_combined_model_of__biocrnpyler_367767_biocrnpyler_317929  \
# 0                                             0.000196
# 1                                             0.000197
# 2                                             0.000197
# 3                                             0.000198
# 4                                             0.000199
# ..                                                 ...
# 920                                           0.000048
# 921                                           0.000048
# 922                                           0.000048
# 923                                           0.000048
# 924                                           0.000048
#
#      atc_i_cell3  ssDNA_comp2  ...  \
# 0    9939.061086         10.0  ...
# 1    9939.987618         10.0  ...
# 2    9940.760665         10.0  ...
# 3    9941.405592         10.0  ...
# 4    9941.943572         10.0  ...
# ..           ...          ...  ...
# 920  9942.993342         10.0  ...
# 921  9942.991861         10.0  ...
# 922  9942.990382         10.0  ...
# 923  9942.988903         10.0  ...
# 924  9942.987424         10.0  ...
#
#      enzyme_kivD_ATP_rheostatbiocrnpyler_317929_combined_model_of__biocrnpyler_367767_biocrnpyler_317929_1_combined  \
# 0                                             0.107110
# 1                                             0.106307
# 2                                             0.105520
# 3                                             0.104750
# 4                                             0.103996
# ..                                                 ...
# 920                                           0.190333
# 921                                           0.190347
# 922                                           0.190362
# 923                                           0.190376
# 924                                           0.190390
#
#      molecule_isobutanal_ATP_rheostatbiocrnpyler_317929_combined_model_of__biocrnpyler_367767_biocrnpyler_317929_1_combined  \
# 0                                             0.443841
# 1                                             0.455734
# 2                                             0.467629
# 3                                             0.479520
# 4                                             0.491403
# ..                                                 ...
# 920                                           0.507354
# 921                                           0.506556
# 922                                           0.505759
# 923                                           0.504965
# 924                                           0.504174
#
#      complex_enzyme_kivD_molecule_3me2oxo_ATP_rheostatbiocrnpyler_317929_combined_model_of__biocrnpyler_367767_biocrnpyler_317929_1_combined  \
# 0                                         7.394719e-08
# 1                                         7.453046e-08
# 2                                         7.510087e-08
# 3                                         7.565888e-08
# 4                                         7.620493e-08
# ..                                                 ...
# 920                                       1.018080e-21
# 921                                       1.105500e-21
# 922                                       1.169733e-21
# 923                                       1.207816e-21
# 924                                       1.216784e-21
#
#      complex_enzyme_kivD_molecule_isobutanal_ATP_rheostatbiocrnpyler_317929_combined_model_of__biocrnpyler_367767_biocrnpyler_317929_1_combined  \
# 0                                             0.092890
# 1                                             0.093693
# 2                                             0.094480
# 3                                             0.095250
# 4                                             0.096004
# ..                                                 ...
# 920                                           0.009667
# 921                                           0.009653
# 922                                           0.009638
# 923                                           0.009624
# 924                                           0.009610
#
#      enzyme_yahk_ATP_rheostatbiocrnpyler_317929_combined_model_of__biocrnpyler_367767_biocrnpyler_317929_1_combined  \
# 0                                             0.016906
# 1                                             0.016439
# 2                                             0.015995
# 3                                             0.015572
# 4                                             0.015169
# ..                                                 ...
# 920                                           0.002298
# 921                                           0.002298
# 922                                           0.002298
# 923                                           0.002298
# 924                                           0.002298
#
#      molecule_isobutanol_ATP_rheostatbiocrnpyler_317929_combined_model_of__biocrnpyler_367767_biocrnpyler_317929_1_combined  \
# 0                                             3.328425
# 1                                             3.435651
# 2                                             3.543850
# 3                                             3.653005
# 4                                             3.763099
# ..                                                 ...
# 920                                          29.285276
# 921                                          29.286090
# 922                                          29.286900
# 923                                          29.287708
# 924                                          29.288514
#
#      complex_enzyme_yahk_metabolite_nadph_molecule_isobutanal_ATP_rheostatbiocrnpyler_317929_combined_model_of__biocrnpyler_367767_biocrnpyler_317929_1_combined  \
# 0                                         6.611308e-08
# 1                                         6.670510e-08
# 2                                         6.728668e-08
# 3                                         6.785811e-08
# 4                                         6.841965e-08
# ..                                                 ...
# 920                                       5.023712e-10
# 921                                       5.007685e-10
# 922                                       4.991735e-10
# 923                                       4.975862e-10
# 924                                       4.960065e-10
#
#      complex_enzyme_yahk_metabolite_nadp_molecule_isobutanol_ATP_rheostatbiocrnpyler_317929_combined_model_of__biocrnpyler_367767_biocrnpyler_317929_1_combined  \
# 0                                             0.183094
# 1                                             0.183561
# 2                                             0.184005
# 3                                             0.184428
# 4                                             0.184831
# ..                                                 ...
# 920                                           0.197702
# 921                                           0.197702
# 922                                           0.197702
# 923                                           0.197702
# 924                                           0.197702
#
#      atc_e_external_reservoir_model_1_combined_1_combined          time
# 0                                            60.938914      3378.378378
# 1                                            59.081369      3423.423423
# 2                                            57.530795      3468.468468
# 3                                            56.236464      3513.513514
# 4                                            55.156029      3558.558559
# ..                                                 ...              ...
# 920                                          49.698531     44819.819820
# 921                                          49.698531     44864.864865
# 922                                          49.698531     44909.909910
# 923                                          49.698531     44954.954955
# 924                                          49.698531     45000.000000
#
# [925 rows x 82 columns]

# %%
gfp_cell3_id3 = cell_3_model.getSpeciesByName('gfp', compartment = 'fusedcell_internal').getId()
exsA_cell2_id2 = cell_2_model.getSpeciesByName('exsA', compartment = 'fusedcell_internal').getId()
exsA_cell3_id3 = cell_3_model.getSpeciesByName('exsA', compartment = 'fusedcell_internal').getId()
gfp_fusedcell_id4 = fused_cell.getSpeciesByName('gfp', compartment = 'fusedcell_internal').getId()
exsA_fusedcell_id4 = fused_cell.getSpeciesByName('exsA', compartment = 'fusedcell_internal').getId()
ATP_id2= cell_2_model.getSpeciesByName('ATP', compartment = 'fusedcell_internal').getId()
ATP_id3= cell_3_model.getSpeciesByName('ATP', compartment = 'fusedcell_internal').getId()
ATP_id4= fused_cell.getSpeciesByName('ATP', compartment = 'fusedcell_internal').getId()
dsDNA_id2 =system2.getSpeciesByName('dsDNA').getId()
vire2b_id2 =system2.getSpeciesByName('VirE2_b').getId()

# %%
colors=['#1b9e77','#d95f02','#7570b3','#e7298a','#66a61e','#e6ab02','#a6761d']
fused_plot = bokeh.plotting.figure(width = 800, height = 450, 
                         x_axis_label = 'time(sec)',
                         y_axis_label = 'concentration',
                         title = 'Export_Fusion_rheostat Plot')
fused_plot.line(t1, r1[gfp_cell3_id3], color = "magenta", line_width = 6, legend_label = 'gfp_cell3')
fused_plot.line(t1, r1[exsA_cell2_id2], color = "cyan",line_width = 3, legend_label = 'exsA_cell2')
fused_plot.line(t1, r1[exsA_cell3_id3], color = "green",line_width = 3, legend_label = 'exsA_cell3')
fused_plot.line(t2, r2[gfp_fusedcell_id4], color = "red", line_width = 3,legend_label = 'gfp_fusedcell')
fused_plot.line(t2, r2[exsA_fusedcell_id4], color = "blue", line_width = 3,legend_label = 'exsA_fusedcell')
fused_plot.line(timepoints, result1[ssDNA_e_id1], color = "brown", line_width = 3,legend_label = 'exported_DNA')
fused_plot.line(timepoints, result1[dsDNA_id2], color = "orange", line_width = 3,legend_label = 'dsDNA')
fused_plot.line(t2, r2[ATP_id4], color = "grey", line_width = 3,legend_label = 'ATP_fusedcell')
#fused_plot.line(t1, r2[ATP_id3], color = "teal", line_width = 3,legend_label = 'ATP_cell3')
#fused_plot.line(t1, r2[ATP_id2], color = "pink", line_width = 3,legend_label = 'ATP_cell2')
fused_plot.line(timepoints, result1[ATP_id1], color = "purple", line_width = 3,legend_label = 'ATP_cell1')



fused_plot.legend.location = 'top_right'
fused_plot.legend.click_policy="hide"

bokeh.io.show(fused_plot)
# Out:
#   <div class="bk-root" id="04c3d529-1c47-429e-8d86-32c5ece358b6" data-root-id="1828"></div>
